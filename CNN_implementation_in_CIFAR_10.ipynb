# %% [markdown]
# # **IMPLEMENTING CNN IN CIFAR-10 DATASET**

# %%
from __future__ import print_function
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.regularizers import l2
import numpy as np
import os

# %%
import matplotlib.pyplot as plt
plt.rcParams['axes.unicode_minus'] = False
plt.style.use('fivethirtyeight')
# %matplotlib inline

# %%
# Defining the parameters
batch_size = 32
num_classes = 10
epochs = 50

# %% [markdown]
# ### Loading and Splitting the dataset

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 2s 0us/step
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %% [markdown]
# ## **Visualisation**

# %%
class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']

fig = plt.figure(figsize=(10,5))
for i in range(num_classes):
    ax = fig.add_subplot(2, 5, 1 + i, xticks=[], yticks=[])
    idx = np.where(y_train[:]==i)[0]
    features_idx = x_train[idx,::]
    img_num = np.random.randint(features_idx.shape[0])
    im = (features_idx[img_num,::])
    ax.set_title(class_names[i])
    plt.imshow(im)
plt.show()

# %% [markdown]
# ## **Pre** **Processing**

# %%
y_train = tf.keras.utils.to_categorical(y_train, num_classes)
y_test = tf.keras.utils.to_categorical(y_test, num_classes)

# %% [markdown]
# # **CNN**

# %%
model = Sequential()
model.add(Conv2D(64, (3, 3), padding='same',
                 input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(128, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Conv2D(128, (3, 3)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512,kernel_regularizer=l2(0.01)))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))

# %% [markdown]
# ##### **Visualising the model**

# %%
pip install visualkeras
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting visualkeras
#   Downloading visualkeras-0.0.2-py3-none-any.whl (12 kB)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from visualkeras) (8.4.0)
# Collecting aggdraw>=1.3.11
#   Downloading aggdraw-1.3.16-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (992 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 992.0/992.0 kB 17.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.9/dist-packages (from visualkeras) (1.22.4)
# Installing collected packages: aggdraw, visualkeras
# Successfully installed aggdraw-1.3.16 visualkeras-0.0.2

# %%
import visualkeras
visualkeras.layered_view(model, scale_xy=10, legend=True)
# Out:
# <PIL.Image.Image image mode=RGBA size=1201x463 at 0x7F605C107BE0>

# %%
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 64)        1792
#
#  activation (Activation)     (None, 32, 32, 64)        0
#
#  batch_normalization (BatchN  (None, 32, 32, 64)       256
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 30, 30, 64)        36928
#
#  activation_1 (Activation)   (None, 30, 30, 64)        0
#
#  batch_normalization_1 (Batc  (None, 30, 30, 64)       256
#  hNormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 15, 15, 64)       0
#  )
#
#  dropout (Dropout)           (None, 15, 15, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 15, 15, 128)       73856
#
#  activation_2 (Activation)   (None, 15, 15, 128)       0
#
#  batch_normalization_2 (Batc  (None, 15, 15, 128)      512
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 13, 13, 128)       147584
#
#  activation_3 (Activation)   (None, 13, 13, 128)       0
#
#  batch_normalization_3 (Batc  (None, 13, 13, 128)      512
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 6, 6, 128)        0
#  2D)
#
#  dropout_1 (Dropout)         (None, 6, 6, 128)         0
#
#  flatten (Flatten)           (None, 4608)              0
#
#  dense (Dense)               (None, 512)               2359808
#
#  activation_4 (Activation)   (None, 512)               0
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 10)                5130
#
#  activation_5 (Activation)   (None, 10)                0
#
# =================================================================
# Total params: 2,626,634
# Trainable params: 2,625,866
# Non-trainable params: 768
# _________________________________________________________________
# None

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='sgd',
              metrics=['accuracy'])

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

# Normalizing the input image
x_train /= 255
x_test /= 255

epochs=50

# Training the model
history = model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True)
# Out:
# Epoch 1/50
# 1563/1563 [==============================] - 32s 13ms/step - loss: 8.5225 - accuracy: 0.4268 - val_loss: 6.3569 - val_accuracy: 0.5158
# Epoch 2/50
# 1563/1563 [==============================] - 17s 11ms/step - loss: 4.9447 - accuracy: 0.5738 - val_loss: 3.7768 - val_accuracy: 0.6362
# Epoch 3/50
# 1563/1563 [==============================] - 17s 11ms/step - loss: 3.0679 - accuracy: 0.6476 - val_loss: 2.5117 - val_accuracy: 0.6603
# Epoch 4/50
# 1563/1563 [==============================] - 17s 11ms/step - loss: 2.0676 - accuracy: 0.6916 - val_loss: 1.7785 - val_accuracy: 0.6983
# Epoch 5/50
# 1563/1563 [==============================] - 18s 11ms/step - loss: 1.5232 - accuracy: 0.7216 - val_loss: 1.3720 - val_accuracy: 0.7272
# Epoch 6/50
# 1563/1563 [==============================] - 18s 12ms/step - loss: 1.2192 - accuracy: 0.7465 - val_loss: 1.1695 - val_accuracy: 0.7451
# Epoch 7/50
# 1563/1563 [==============================] - 18s 11ms/step - loss: 1.0586 - accuracy: 0.7633 - val_loss: 0.9918 - val_accuracy: 0.7774
# Epoch 8/50
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.9601 - accuracy: 0.7759 - val_loss: 0.9535 - val_accuracy: 0.7772
# Epoch 9/50
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.8929 - accuracy: 0.7914 - val_loss: 0.9506 - val_accuracy: 0.7742
# Epoch 10/50
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.8514 - accuracy: 0.8041 - val_loss: 0.9166 - val_accuracy: 0.7853
# Epoch 11/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.8241 - accuracy: 0.8150 - val_loss: 0.9300 - val_accuracy: 0.7811
# Epoch 12/50
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.8022 - accuracy: 0.8255 - val_loss: 0.9249 - val_accuracy: 0.7872
# Epoch 13/50
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.7869 - accuracy: 0.8325 - val_loss: 0.9014 - val_accuracy: 0.8042
# Epoch 14/50
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.7761 - accuracy: 0.8418 - val_loss: 0.9354 - val_accuracy: 0.7967
# Epoch 15/50
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.7757 - accuracy: 0.8473 - val_loss: 0.8897 - val_accuracy: 0.8140
# Epoch 16/50
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.7690 - accuracy: 0.8528 - val_loss: 0.9259 - val_accuracy: 0.8115
# Epoch 17/50
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.7660 - accuracy: 0.8603 - val_loss: 0.9491 - val_accuracy: 0.8093
# Epoch 18/50
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.7768 - accuracy: 0.8620 - val_loss: 0.9399 - val_accuracy: 0.8183
# Epoch 19/50
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.7750 - accuracy: 0.8674 - val_loss: 1.0034 - val_accuracy: 0.8045
# Epoch 20/50
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.7742 - accuracy: 0.8707 - val_loss: 0.9726 - val_accuracy: 0.8161
# Epoch 21/50
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.7775 - accuracy: 0.8735 - val_loss: 0.9632 - val_accuracy: 0.8247
# Epoch 22/50
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.7659 - accuracy: 0.8817 - val_loss: 1.0185 - val_accuracy: 0.8032
# Epoch 23/50
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.7640 - accuracy: 0.8830 - val_loss: 0.9967 - val_accuracy: 0.8250
# Epoch 24/50
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.7631 - accuracy: 0.8864 - val_loss: 0.9884 - val_accuracy: 0.8300
# Epoch 25/50
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.7689 - accuracy: 0.8868 - val_loss: 0.9929 - val_accuracy: 0.8245
# Epoch 26/50
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.7722 - accuracy: 0.8891 - val_loss: 1.0065 - val_accuracy: 0.8271
# Epoch 27/50
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.7701 - accuracy: 0.8931 - val_loss: 1.0020 - val_accuracy: 0.8277
# Epoch 28/50
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.7580 - accuracy: 0.8973 - val_loss: 0.9951 - val_accuracy: 0.8333
# Epoch 29/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.7503 - accuracy: 0.9004 - val_loss: 1.0126 - val_accuracy: 0.8291
# Epoch 30/50
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.7577 - accuracy: 0.8988 - val_loss: 1.0356 - val_accuracy: 0.8249
# Epoch 31/50
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.7553 - accuracy: 0.9038 - val_loss: 1.0977 - val_accuracy: 0.8107
# Epoch 32/50
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.7494 - accuracy: 0.9039 - val_loss: 1.0080 - val_accuracy: 0.8360
# Epoch 33/50
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.7476 - accuracy: 0.9062 - val_loss: 1.0855 - val_accuracy: 0.8190
# Epoch 34/50
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.7484 - accuracy: 0.9068 - val_loss: 1.0512 - val_accuracy: 0.8264
# Epoch 35/50
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.7467 - accuracy: 0.9079 - val_loss: 1.0357 - val_accuracy: 0.8311
# Epoch 36/50
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.7413 - accuracy: 0.9106 - val_loss: 1.0825 - val_accuracy: 0.8120
# Epoch 37/50
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.7426 - accuracy: 0.9100 - val_loss: 1.0341 - val_accuracy: 0.8278
# Epoch 38/50
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.7425 - accuracy: 0.9114 - val_loss: 1.0370 - val_accuracy: 0.8305
# Epoch 39/50
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.7351 - accuracy: 0.9130 - val_loss: 1.0219 - val_accuracy: 0.8385
# Epoch 40/50
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.7385 - accuracy: 0.9141 - val_loss: 1.0807 - val_accuracy: 0.8235
# Epoch 41/50
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.7321 - accuracy: 0.9157 - val_loss: 1.0613 - val_accuracy: 0.8325
# Epoch 42/50
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.7349 - accuracy: 0.9138 - val_loss: 1.0436 - val_accuracy: 0.8371
# Epoch 43/50
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.7253 - accuracy: 0.9187 - val_loss: 1.0410 - val_accuracy: 0.8333
# Epoch 44/50
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.7215 - accuracy: 0.9193 - val_loss: 1.0712 - val_accuracy: 0.8204
# Epoch 45/50
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.7173 - accuracy: 0.9191 - val_loss: 1.0496 - val_accuracy: 0.8328
# Epoch 46/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.7259 - accuracy: 0.9180 - val_loss: 1.0947 - val_accuracy: 0.8253
# Epoch 47/50
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.7202 - accuracy: 0.9205 - val_loss: 1.0480 - val_accuracy: 0.8370
# Epoch 48/50
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.7091 - accuracy: 0.9248 - val_loss: 1.0330 - val_accuracy: 0.8419
# Epoch 49/50
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.7066 - accuracy: 0.9236 - val_loss: 1.0293 - val_accuracy: 0.8388
# Epoch 50/50
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.6981 - accuracy: 0.9250 - val_loss: 1.0476 - val_accuracy: 0.8319

# %% [markdown]
# **Evaluating the model**

# %%
plt.figure(figsize=[20,8])

# summarize history for accuracy
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy', size=25, pad=20)
plt.ylabel('Accuracy', size=15)
plt.xlabel('Epoch', size=15)
plt.legend(['train', 'test'], loc='upper left')
# summarize history for loss

plt.subplot(1,2,2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss', size=25, pad=20)
plt.ylabel('Loss', size=15)
plt.xlabel('Epoch', size=15)
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# **Prediction using the model**

# %%
predictions = model.predict(x_test)

plt.figure(figsize=[10,10])

class_names = ['airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck']

plt.subplot(2,2,1)
n = 3
plt.imshow(x_test[n].reshape(32, 32, -1), cmap=plt.cm.binary)
plt.title("Predicted value: " + str(class_names[np.argmax(predictions[n], axis=0)]), size=20)
plt.grid(False)

plt.subplot(2,2,2)
n = 4
plt.imshow(x_test[n].reshape(32, 32, -1), cmap=plt.cm.binary)
plt.title("Predicted value: " + str(class_names[np.argmax(predictions[n], axis=0)]), size=20)
plt.grid(False)

plt.subplot(2,2,3)
n = 8
plt.imshow(x_test[n].reshape(32, 32, -1), cmap=plt.cm.binary)
plt.title("Predicted value: " + str(class_names[np.argmax(predictions[n], axis=0)]), size=20)
plt.grid(False)

plt.subplot(2,2,4)
n = 6
plt.imshow(x_test[n].reshape(32, 32, -1), cmap=plt.cm.binary)
plt.title("Predicted value: " + str(class_names[np.argmax(predictions[n], axis=0)]), size=20)
plt.grid(False)

plt.suptitle("Predictions of CIFAR-10 Data", size=30, color="#6166B3")

plt.show()
# Out:
# 313/313 [==============================] - 1s 3ms/step
